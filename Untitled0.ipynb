# %% [markdown]
# <a href="https://colab.research.google.com/github/ljc0507/3Dblender/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
<!DOCTYPE html>
<html lang="zh-Hant">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>2026 全球科技與產業趨勢智慧決策儀表板 Pro</title>
    <!-- Tailwind CSS -->
    <script src="https://cdn.tailwindcss.com"></script>
    <!-- Lucide Icons -->
    <script src="https://unpkg.com/lucide@latest"></script>
    <!-- Google Fonts -->
    <style>
        @import url('https://fonts.googleapis.com/css2?family=JetBrains+Mono:wght@400;700&family=Noto+Sans+TC:wght@300;400;500;700;900&display=swap');
        body {
            font-family: 'Noto Sans TC', sans-serif;
            background-color: #0b0f19;
        }
        /* Custom scrollbar for premium look */
        ::-webkit-scrollbar {
            width: 6px;
            height: 6px;
        }
        ::-webkit-scrollbar-track {
            background: #0f172a;
        }
        ::-webkit-scrollbar-thumb {
            background: #334155;
            border-radius: 4px;
        }
        ::-webkit-scrollbar-thumb:hover {
            background: #6366f1;
        }
        .glow-border:hover {
            box-shadow: 0 0 15px rgba(99, 102, 241, 0.2);
        }
    </style>
</head>
<body class="text-slate-100 antialiased min-h-screen flex flex-col">

    <!-- Premium Navigation Bar -->
    <header class="border-b border-slate-800/80 bg-slate-900/90 backdrop-blur sticky top-0 z-50 px-4 lg:px-8 py-3">
        <div class="max-w-7xl mx-auto flex flex-col md:flex-row items-center justify-between gap-4">
            <div class="flex items-center gap-3">
                <div class="bg-gradient-to-tr from-indigo-600 to-violet-500 p-2.5 rounded-xl shadow-lg shadow-indigo-500/20">
                    <i data-lucide="bar-chart-3" class="w-6 h-6 text-white"></i>
                </div>
                <div>
                    <div class="flex items-center gap-2">
                        <h1 class="text-xl font-black tracking-tight bg-gradient-to-r from-white via-slate-100 to-indigo-300 bg-clip-text text-transparent">
                            ASC 全球重點新聞與產業趨勢週報 <span class="text-indigo-400">PRO</span>
                        </h1>
                        <span class="px-2 py-0.5 text-[10px] font-bold bg-indigo-500/10 text-indigo-300 rounded-full border border-indigo-500/20">
                            情報特刊：05/18 - 05/22
                        </span>
                    </div>
                    <p class="text-[11px] text-slate-400">基於資深情報專家視角的 30 篇全球科技、宏觀總經與特化材料深度交叉對比</p>
                </div>
            </div>

            <div class="flex items-center gap-3">
                <div class="bg-slate-950/80 px-3 py-1.5 rounded-lg border border-slate-800 flex items-center gap-1.5 text-xs text-slate-400">
                    <span class="w-2 h-2 rounded-full bg-emerald-500 animate-ping"></span>
                    <span>系統時間: 2026-05-21 14:46</span>
                </div>
                <button onclick="openExportModal()" class="flex items-center gap-1.5 bg-indigo-600 hover:bg-indigo-500 text-white px-3.5 py-1.5 rounded-lg text-xs font-bold transition-all shadow-md shadow-indigo-600/10 active:scale-95">
                    <i data-lucide="download" class="w-3.5 h-3.5"></i>
                    匯出深度解讀報告
                </button>
            </div>
        </div>
    </header>

    <main class="flex-1 max-w-7xl w-full mx-auto px-4 lg:px-8 py-6 space-y-6">

        <!-- Phase 1: Interactive Sentiment Gauge & Executive Summary -->
        <section class="grid grid-cols-1 lg:grid-cols-3 gap-6">

            <!-- Left & Mid Column: Executive Dynamic Insights -->
            <div class="lg:col-span-2 bg-gradient-to-br from-slate-900/90 to-slate-950 border border-slate-800/80 p-6 rounded-2xl relative overflow-hidden flex flex-col justify-between">
                <div class="absolute -right-16 -top-16 w-48 h-48 bg-indigo-500/5 rounded-full blur-3xl pointer-events-none"></div>

                <div class="space-y-4">
                    <div class="flex items-center gap-2 text-indigo-400 text-xs font-bold uppercase tracking-widest">
                        <i data-lucide="compass" class="w-4 h-4"></i>
                        <span>第一階段：核心全域綜覽</span>
                    </div>
                    <h2 class="text-xl font-bold text-white leading-snug">當週核心情報：AI 算力極限狂熱與高息環境的雙重拉扯</h2>
                    <p class="text-slate-300 text-sm leading-relaxed">
                        近期全球產業受到「AI 算力擴張」與「高通膨高利率」雙重夾擊。半導體板塊因台積電先進製程（2奈米良率進程、CoWoS破98%良率）以及韓廠 HBM 競速而極度火熱，但傳統記憶體板塊卻因長鑫存儲（CXMT）擴產至每月 28~30 萬片引爆 2027 下半年過剩疑慮。美元高息導致台幣及亞幣防守吃緊，台灣外銷受惠 AI 及傳產急單呈雙位數增長（4月外銷高達874億美元，年增48%），但「K型分化」及特材 PFAS 環保法規限令，正迫使特化與綠能供應鏈面臨嚴酷的重組與汰弱留強。
                    </p>
                </div>

                <div class="mt-6 pt-4 border-t border-slate-800/80">
                    <span class="text-xs font-bold text-indigo-300 block mb-3">關鍵字矩陣與熱度：</span>
                    <div class="flex flex-wrap gap-2">
                        <span class="px-2.5 py-1 text-xs rounded-lg bg-indigo-500/10 text-indigo-300 border border-indigo-500/20 font-medium">HBM4 / 1c DRAM (極熱)</span>
                        <span class="px-2.5 py-1 text-xs rounded-lg bg-amber-500/10 text-amber-300 border border-amber-500/20 font-medium">傳統DRAM 供過於求 (震盪)</span>
                        <span class="px-2.5 py-1 text-xs rounded-lg bg-rose-500/10 text-rose-300 border border-rose-500/20 font-medium">PFAS 替代/雙相液冷 (爆發)</span>
                        <span class="px-2.5 py-1 text-xs rounded-lg bg-emerald-500/10 text-emerald-300 border border-emerald-500/20 font-medium">K型經濟 (隱憂)</span>
                        <span class="px-2.5 py-1 text-xs rounded-lg bg-sky-500/10 text-sky-300 border border-sky-500/20 font-medium">低軌衛星 SpaceX IPO (吸金)</span>
                    </div>
                </div>
            </div>

            <!-- Right Column: Interactive Sentiment Gauges -->
            <div class="bg-slate-900/60 border border-slate-800/80 p-6 rounded-2xl flex flex-col justify-between">
                <div>
                    <h3 class="text-xs font-bold text-slate-400 uppercase tracking-widest mb-4 flex items-center gap-1.5">
                        <i data-lucide="gauge" class="w-4 h-4 text-indigo-400"></i>
                        即時產業情緒雷達
                    </h3>

                    <div class="space-y-4">
                        <!-- AI & TSMC advanced tech -->
                        <div class="space-y-1">
                            <div class="flex justify-between text-xs font-bold">
                                <span class="text-slate-300">AI 算力與先進封裝</span>
                                <span class="text-indigo-400">極度擴張 (96%)</span>
                            </div>
                            <div class="w-full bg-slate-950 h-2 rounded-full overflow-hidden">
                                <div class="bg-indigo-500 h-full w-[96%]"></div>
                            </div>
                        </div>

                        <!-- DRAM & NAND Flash -->
                        <div class="space-y-1">
                            <div class="flex justify-between text-xs font-bold">
                                <span class="text-slate-300">記憶體供給恐慌度</span>
                                <span class="text-amber-500">劇烈震盪 (78%)</span>
                            </div>
                            <div class="w-full bg-slate-950 h-2 rounded-full overflow-hidden">
                                <div class="bg-amber-500 h-full w-[78%]"></div>
                            </div>
                        </div>

                        <!-- Macro Currency -->
                        <div class="space-y-1">
                            <div class="flex justify-between text-xs font-bold">
                                <span class="text-slate-300">台幣匯率與利差壓力</span>
                                <span class="text-rose-400">防守邊緣 (82%)</span>
                            </div>
                            <div class="w-full bg-slate-950 h-2 rounded-full overflow-hidden">
                                <div class="bg-rose-500 h-full w-[82%]"></div>
                            </div>
                        </div>

                        <!-- Clean Tech -->
                        <div class="space-y-1">
                            <div class="flex justify-between text-xs font-bold">
                                <span class="text-slate-300">中國新能源洗牌深度</span>
                                <span class="text-emerald-400">產能出清 (70%)</span>
                            </div>
                            <div class="w-full bg-slate-950 h-2 rounded-full overflow-hidden">
                                <div class="bg-emerald-500 h-full w-[70%]"></div>
                            </div>
                        </div>
                    </div>
                </div>

                <!-- Simulation Info Alert -->
                <div class="bg-indigo-950/20 border border-indigo-900/30 p-3.5 rounded-xl text-[11px] text-slate-300 leading-relaxed mt-4">
                    <strong class="text-indigo-300">情報解讀提示：</strong>
                    大盤失守、均線走弱之際，低軌衛星（敬鵬、事欣科）連拉漲停、传统石化（台塑化）逆勢走強，反映出高風險偏好資金正向「防禦性低估值」及「SpaceX IPO 催化劑」板塊移防。
                </div>
            </div>
        </section>

        <!-- Phase 2: Domain Intelligence Hub (Dynamic Tabs) -->
        <section class="bg-slate-900 border border-slate-800/80 rounded-2xl overflow-hidden shadow-xl">
            <div class="border-b border-slate-800 bg-slate-950/60 px-6 py-4 flex flex-col md:flex-row md:items-center justify-between gap-4">
                <div class="flex items-center gap-2">
                    <i data-lucide="compass" class="text-indigo-400 w-5 h-5"></i>
                    <div>
                        <h3 class="font-bold text-slate-200">第二階段：四大領域專項深度分析</h3>
                        <p class="text-[11px] text-slate-400 mt-0.5">點選下方標籤切換查看各版塊之核心情報、關鍵指標與競爭格局</p>
                    </div>
                </div>
                <!-- Dynamic Pill Switcher -->
                <div class="flex flex-wrap gap-1 bg-slate-900 p-1 rounded-lg border border-slate-800">
                    <button onclick="switchTab('semi')" id="tab-semi" class="tab-btn px-4 py-1.5 rounded-md text-xs font-bold transition-all bg-indigo-600 text-white shadow">
                        半導體產業
                    </button>
                    <button onclick="switchTab('macro')" id="tab-macro" class="tab-btn px-4 py-1.5 rounded-md text-xs font-bold transition-all text-slate-400 hover:text-white">
                        全球市場經濟
                    </button>
                    <button onclick="switchTab('energy')" id="tab-energy" class="tab-btn px-4 py-1.5 rounded-md text-xs font-bold transition-all text-slate-400 hover:text-white">
                        石化／綠能產業
                    </button>
                    <button onclick="switchTab('fluorine')" id="tab-fluorine" class="tab-btn px-4 py-1.5 rounded-md text-xs font-bold transition-all text-slate-400 hover:text-white">
                        氟化工／散熱
                    </button>
                </div>
            </div>

            <!-- Tab Content: Semiconductor -->
            <div id="content-semi" class="tab-content p-6 space-y-6">
                <div class="grid grid-cols-1 lg:grid-cols-3 gap-6">
                    <div class="space-y-4">
                        <span class="px-2 py-0.5 text-[10px] font-bold bg-indigo-500/10 text-indigo-300 rounded border border-indigo-500/20">技術突破點</span>
                        <h4 class="text-base font-bold text-white">台積電先進製程良率超車 & COUPE 矽光子藍圖</h4>
                        <p class="text-xs text-slate-300 leading-relaxed">
                            台積電 2 奈米（N2）良率學習曲線超前，第一年晶圓產出將大增 45%。CoWoS 先進封裝良率突破 98%，計畫 2028 年推出 14倍光罩尺寸（支援 20 顆 HBM）、2029 升級至支援 24 顆 HBM，並推進 SoW 技術（可整合 64 顆 HBM 與 16 個 CoWoS）。為因應 1.6MW 的超級機櫃，高速傳輸由銅退光，全面導入 <strong class="text-indigo-300">COUPE 矽光子與全光網路 (CPO)</strong> 異質整合架構。
                        </p>
                    </div>
                    <div class="space-y-4 border-t lg:border-t-0 lg:border-x border-slate-800/80 px-0 lg:px-6">
                        <span class="px-2 py-0.5 text-[10px] font-bold bg-amber-500/10 text-amber-300 rounded border border-amber-500/20">供給反轉警訊</span>
                        <h4 class="text-base font-bold text-white">中國大擴產 vs. 記憶體 2027 供過於求恐慌</h4>
                        <p class="text-xs text-slate-300 leading-relaxed">
                            三星 HBM3E 核心 DRAM 晶片（1b）良率大突圍衝上 92%，下代 HBM4 核心（1c）良率亦破 75%。然而，中國記憶體大廠長鑫存儲（CXMT）DRAM 產能預計於 2025 年底拉升至 28~30 萬片/月。前三星總裁慶桂顯及硬碟大廠希捷執行長 Dave Mosley 接連示警：產能盲目擴充恐使 <strong class="text-amber-400">2027 年下半年迎來價格全面反轉與需求收縮</strong>，引發記憶體股暴量殺盤，台股南亞科、華邦電摜入跌停。
                        </p>
                    </div>
                    <div class="space-y-4">
                        <span class="px-2 py-0.5 text-[10px] font-bold bg-rose-500/10 text-rose-300 rounded border border-rose-500/20">競爭格局劇變</span>
                        <h4 class="text-base font-bold text-white">Arm 遭 FTC 反壟斷調查 & Intel 封裝分流</h4>
                        <p class="text-xs text-slate-300 leading-relaxed">
                            安謀（Arm）於 2026 年 3 月跨足自研 AGI CPU，與原授權客戶（高通等）直接競爭，引發「又當裁判兼選手」的警惕，遭美國 FTC 正式發起反壟斷調查。同時，台積電高階產能極度短缺促使 SK 海力士、Apple、Google 將部分代工或先進封裝訂單分流至 Intel。Intel 先進封裝良率已提升至量產水準，成為第二供貨源。
                        </p>
                    </div>
                </div>
                <!-- Mini Visual Stats -->
                <div class="grid grid-cols-2 md:grid-cols-4 gap-4 pt-4 border-t border-slate-800/80 text-xs">
                    <div class="bg-slate-950 p-3 rounded-xl border border-slate-800/50">
                        <span class="text-slate-400 block">台積電 CoWoS 良率</span>
                        <span class="text-emerald-400 font-bold text-lg">&gt; 98.0%</span>
                    </div>
                    <div class="bg-slate-950 p-3 rounded-xl border border-slate-800/50">
                        <span class="text-slate-400 block">三星 1b DRAM 良率</span>
                        <span class="text-emerald-400 font-bold text-lg">92.0%</span>
                    </div>
                    <div class="bg-slate-950 p-3 rounded-xl border border-slate-800/50">
                        <span class="text-slate-400 block">長鑫存儲 DRAM 月產能 (2025e)</span>
                        <span class="text-amber-500 font-bold text-lg">28 ~ 30萬片</span>
                    </div>
                    <div class="bg-slate-950 p-3 rounded-xl border border-slate-800/50">
                        <span class="text-slate-400 block">台積電年新增建廠速度</span>
                        <span class="text-indigo-400 font-bold text-lg">9座新廠/年</span>
                    </div>
                </div>
            </div>

            <!-- Tab Content: Macro Economy -->
            <div id="content-macro" class="tab-content p-6 space-y-6 hidden">
                <div class="grid grid-cols-1 lg:grid-cols-3 gap-6">
                    <div class="space-y-4">
                        <span class="px-2 py-0.5 text-[10px] font-bold bg-emerald-500/10 text-emerald-300 rounded border border-emerald-500/20">貨幣防守戰</span>
                        <h4 class="text-base font-bold text-white">強勢美元重壓 & 新台幣硬守 31.6 元關卡</h4>
                        <p class="text-xs text-slate-300 leading-relaxed">
                            美債 30 年期及 10 年期殖利率狂飆至多年高點，中美利差倒掛一度擴大至 293 個基點，導致外資連續 12 個月減持陸債。新台幣於 20 日開盤跌破 31.7 元。出口商順勢拋匯加上台灣央行由放任貶值轉為強勢介入操作，調節力道顯著擴大，尾盤回穩收於 31.643 元，硬守 31.6 元防線。同時，印尼央行意外升息 2 碼以捍衛本幣。
                        </p>
                    </div>
                    <div class="space-y-4 border-t lg:border-t-0 lg:border-x border-slate-800/80 px-0 lg:px-6">
                        <span class="px-2 py-0.5 text-[10px] font-bold bg-amber-500/10 text-amber-300 rounded border border-amber-500/20">K型分化警戒</span>
                        <h4 class="text-base font-bold text-white">渣打預測 GDP 9.5% 與結構性「科技熱、傳產冷」</h4>
                        <p class="text-xs text-slate-300 leading-relaxed">
                            受惠 AI 晶片出口爆發，台灣 4 月外銷訂單創史上次高達 874 億美元（資通信成長達 90%）。渣打銀行大舉上修台灣全年 GDP 預測至 9.5%，但示警台灣已陷入嚴重的「K型經濟」。成長紅利高度向高科技傾斜，而佔台灣近 90% 就業人口的傳統與民生產業面臨外需疲弱、電價大漲與通膨高漲（58% 民眾預期通膨高於 2%）的實質降薪壓力。
                        </p>
                    </div>
                    <div class="space-y-4">
                        <span class="px-2 py-0.5 text-[10px] font-bold bg-indigo-500/10 text-indigo-300 rounded border border-indigo-500/20">地緣政治與政策</span>
                        <h4 class="text-base font-bold text-white">520 執政兩週年賴總統 4 大國政願景</h4>
                        <p class="text-xs text-slate-300 leading-relaxed">
                            總統賴清德於就職兩週年提出「維持現狀、堅守主權」、「中小微企業千億轉型計畫」、「0至18歲每月5,000元成長津貼」以及「補強國防軍購」等四大國政。川普已公開表示將與賴總統通話，推動解決台灣問題，但對台 140 億美元軍售與對中國 H200/RTX5090 遊戲晶片出口限制之美中博弈仍暗流洶湧。
                        </p>
                    </div>
                </div>
                <!-- Mini Visual Stats -->
                <div class="grid grid-cols-2 md:grid-cols-4 gap-4 pt-4 border-t border-slate-800/80 text-xs">
                    <div class="bg-slate-950 p-3 rounded-xl border border-slate-800/50">
                        <span class="text-slate-400 block">4月外銷訂單年增率</span>
                        <span class="text-emerald-400 font-bold text-lg">+48.1% (874億美元)</span>
                    </div>
                    <div class="bg-slate-950 p-3 rounded-xl border border-slate-800/50">
                        <span class="text-slate-400 block">外國債券外資持有規模 (陸債)</span>
                        <span class="text-rose-400 font-bold text-lg">3.12 兆元 (歷史低點)</span>
                    </div>
                    <div class="bg-slate-950 p-3 rounded-xl border border-slate-800/50">
                        <span class="text-slate-400 block">渣打預測台灣今年 GDP</span>
                        <span class="text-indigo-400 font-bold text-lg">9.5% (科技獨熱)</span>
                    </div>
                    <div class="bg-slate-950 p-3 rounded-xl border border-slate-800/50">
                        <span class="text-slate-400 block">聯合國下調今年全球 GDP</span>
                        <span class="text-amber-500 font-bold text-lg">至 2.5% (原預估 2.7%)</span>
                    </div>
                </div>
            </div>

            <!-- Tab Content: Petrochemical & Energy -->
            <div id="content-energy" class="tab-content p-6 space-y-6 hidden">
                <div class="grid grid-cols-1 lg:grid-cols-3 gap-6">
                    <div class="space-y-4">
                        <span class="px-2 py-0.5 text-[10px] font-bold bg-amber-500/10 text-amber-300 rounded border border-amber-500/20">綠能出清危機</span>
                        <h4 class="text-base font-bold text-white">中國新能源極度洗牌：年底四成氫能倒閉</h4>
                        <p class="text-xs text-slate-300 leading-relaxed">
                            上海氫通能源高層於論壇指出：「到今年底，氫能行業預計有 40% 企業倒閉；2029年僅剩 10% 能存活。」中國太陽能與氫能面臨嚴酷的價格戰與低效產能出清。隆基、通威等巨頭首季全線虧損，地方政府已被嚴令禁止救援。與此同時，多晶矽大廠協鑫科技積極將樂山與徐州廠進行技術升級，轉向 LFP（年產 20 萬噸磷酸鐵鋰電池）與矽碳負極材料平台。
                        </p>
                    </div>
                    <div class="space-y-4 border-t lg:border-t-0 lg:border-x border-slate-800/80 px-0 lg:px-6">
                        <span class="px-2 py-0.5 text-[10px] font-bold bg-rose-500/10 text-rose-300 rounded border border-rose-500/20">技術輸出紅線</span>
                        <h4 class="text-base font-bold text-white">北京收緊鋰電技術出口：印度直接採購成品</h4>
                        <p class="text-xs text-slate-300 leading-relaxed">
                            因應北京政府嚴格封鎖先進鋰離子電池生產技術的外移限制，印度最大集團信實工業（Reliance Industries）原本與廈門海辰儲能、寧德時代的技術移轉合資建廠談判宣告破裂。最終，信實工業被迫放棄印度本地電芯自製計畫，改為「直接向寧德時代採購儲能系統成品」，凸顯中國在動力與儲能電池供應鏈的壟斷性控制力。
                        </p>
                    </div>
                    <div class="space-y-4">
                        <span class="px-2 py-0.5 text-[10px] font-bold bg-indigo-500/10 text-indigo-300 rounded border border-indigo-500/20">政策與碳稅</span>
                        <h4 class="text-base font-bold text-white">櫃買中心推出「轉型債」& 石化股資金避險</h4>
                        <p class="text-xs text-slate-300 leading-relaxed">
                            為協助石化及鋼鐵等排碳大戶轉型，台灣櫃買中心擬推出「轉型債」融資工具。在中東局勢不穩支撐原物料油價的背景下，傳統石化股（台塑化、中石化、新海、山隆）憑藉低基期、低估值與題材面支持，在台股跌破月線的空頭盤勢中，成為短期防禦性資金的關鍵避風港。
                        </p>
                    </div>
                </div>
                <!-- Mini Visual Stats -->
                <div class="grid grid-cols-2 md:grid-cols-4 gap-4 pt-4 border-t border-slate-800/80 text-xs">
                    <div class="bg-slate-950 p-3 rounded-xl border border-slate-800/50">
                        <span class="text-slate-400 block">協鑫 LFP 電池年產能</span>
                        <span class="text-emerald-400 font-bold text-lg">20 萬噸</span>
                    </div>
                    <div class="bg-slate-950 p-3 rounded-xl border border-slate-800/50">
                        <span class="text-slate-400 block">氫能年底預計消亡率</span>
                        <span class="text-rose-400 font-bold text-lg">40.0%</span>
                    </div>
                    <div class="bg-slate-950 p-3 rounded-xl border border-slate-800/50">
                        <span class="text-slate-400 block">IEA 全球新車電動車佔比</span>
                        <span class="text-indigo-400 font-bold text-lg">接近 30%</span>
                    </div>
                    <div class="bg-slate-950 p-3 rounded-xl border border-slate-800/50">
                        <span class="text-slate-400 block">協鑫科技 2025 淨虧損</span>
                        <span class="text-amber-500 font-bold text-lg">人民幣 28.7 億元</span>
                    </div>
                </div>
            </div>

            <!-- Tab Content: Fluorine Chemical & Cooling -->
            <div id="content-fluorine" class="tab-content p-6 space-y-6 hidden">
                <div class="grid grid-cols-1 lg:grid-cols-3 gap-6">
                    <div class="space-y-4">
                        <span class="px-2 py-0.5 text-[10px] font-bold bg-rose-500/10 text-rose-300 rounded border border-rose-500/20">環保限令衝擊</span>
                        <h4 class="text-base font-bold text-white">PFAS REACH 歐盟法規禁令之材料革命</h4>
                        <p class="text-xs text-slate-300 leading-relaxed">
                            PFAS（全氟與多氟烷基物質）由於優異的耐高溫、耐腐蝕及低介電特性，在晶圓蝕刻耗材、鋰電池阻燃、AI 資料中心冷卻液中具備不可替代性。然而，歐盟 REACH 發起戰略禁令，強制去氟化。短期內難以完全消滅，驅使產業正全面往「低氟化」與「無氟替代」（如矽系替代、生質高分子與無氟冷卻液）技術快速升級，成為台廠高值化轉型新商機。
                        </p>
                    </div>
                    <div class="space-y-4 border-t lg:border-t-0 lg:border-x border-slate-800/80 px-0 lg:px-6">
                        <span class="px-2 py-0.5 text-[10px] font-bold bg-indigo-500/10 text-indigo-300 rounded border border-indigo-500/20">超級機櫃功耗限制</span>
                        <h4 class="text-base font-bold text-white">單機櫃 1.6MW 極限功耗逼退「純銅方案」</h4>
                        <p class="text-xs text-slate-300 leading-relaxed">
                            廣達費曼研究中心指出，未來 AI 伺服器機櫃 ASIC 晶片量將暴增至 500 顆，功耗劇增 200 倍、直奔 1.6MW 的物理極限。高傳輸速度下，高電壓 800V 直流架構（HVDC）以及「光傳輸取代銅傳輸」成為唯一選擇。資料中心必須快速導入全光化（COUPE/CPO）架構與雙相直接液冷（2P DLC）整櫃方案。
                        </p>
                    </div>
                    <div class="space-y-4">
                        <span class="px-2 py-0.5 text-[10px] font-bold bg-emerald-500/10 text-emerald-300 rounded border border-emerald-500/20">前鋒台廠進程</span>
                        <h4 class="text-base font-bold text-white">台廠冷卻與材料先鋒技術落地</h4>
                        <p class="text-xs text-slate-300 leading-relaxed">
                            台廠「其曜」搶先發表 2P DLC 雙相直接液冷整櫃解決方案，結合去 PFAS、高導熱能效，大幅減低大型 AI Factory 的 PUE 值。同時，PCB 與銅箔基板廠因應高頻、低介電與去氟材料限制，正與特化廠合作開發新型矽基與聚醯亞胺（PI）等高頻低耗損去氟板材，成為 AI 基建的隱形護城河。
                        </p>
                    </div>
                </div>
                <!-- Mini Visual Stats -->
                <div class="grid grid-cols-2 md:grid-cols-4 gap-4 pt-4 border-t border-slate-800/80 text-xs">
                    <div class="bg-slate-950 p-3 rounded-xl border border-slate-800/50">
                        <span class="text-slate-400 block">AI單機櫃極限功耗(ASIC)</span>
                        <span class="text-rose-400 font-bold text-lg">1.6 MW (增200倍)</span>
                    </div>
                    <div class="bg-slate-950 p-3 rounded-xl border border-slate-800/50">
                        <span class="text-slate-400 block">傳統銅線傳輸極限速率</span>
                        <span class="text-amber-500 font-bold text-lg">224G ~ 448G (拐點)</span>
                    </div>
                    <div class="bg-slate-950 p-3 rounded-xl border border-slate-800/50">
                        <span class="text-slate-400 block">台廠液冷關鍵方案商</span>
                        <span class="text-indigo-400 font-bold text-lg">其曜 / 2P DLC 方案</span>
                    </div>
                    <div class="bg-slate-950 p-3 rounded-xl border border-slate-800/50">
                        <span class="text-slate-400 block">歐盟PFAS全面限令時程</span>
                        <span class="text-emerald-400 font-bold text-lg">戰略限期退場中</span>
                    </div>
                </div>
            </div>
        </section>

        <!-- Phase 3: Interactive Intelligence Chain Sandbox -->
        <section class="bg-slate-900 border border-slate-800/80 p-6 rounded-2xl space-y-6">
            <div class="flex items-center gap-2 border-b border-slate-800 pb-3">
                <i data-lucide="network" class="text-indigo-400 w-5 h-5"></i>
                <div>
                    <h3 class="font-bold text-slate-200">第三階段：跨領域連鎖反應模擬沙盒</h3>
                    <p class="text-xs text-slate-400 mt-0.5">點擊左側核心因子，即可動態追蹤與高亮整條產業鏈的骨牌效應路徑與專家評估</p>
                </div>
            </div>

            <div class="grid grid-cols-1 lg:grid-cols-12 gap-6">
                <!-- Trigger Controllers (Left) -->
                <div class="lg:col-span-4 space-y-3">
                    <span class="text-xs font-bold text-slate-400 uppercase tracking-widest block mb-2">1. 選擇事件核心起因</span>

                    <button onclick="simulateChain(1)" id="chain-btn-1" class="chain-btn w-full text-left p-3.5 rounded-xl border border-slate-800 bg-slate-950 hover:border-indigo-500/50 transition-all flex items-center justify-between group active:scale-98">
                        <div class="space-y-1">
                            <span class="text-xs font-bold text-indigo-400">連鎖路徑 A</span>
                            <p class="text-xs font-semibold text-slate-200">美債高利率與利差大倒掛</p>
                        </div>
                        <i data-lucide="arrow-right" class="w-4 h-4 text-slate-500 group-hover:text-indigo-400 transform group-hover:translate-x-1 transition-all"></i>
                    </button>

                    <button onclick="simulateChain(2)" id="chain-btn-2" class="chain-btn w-full text-left p-3.5 rounded-xl border border-slate-800 bg-slate-950 hover:border-amber-500/50 transition-all flex items-center justify-between group active:scale-98">
                        <div class="space-y-1">
                            <span class="text-xs font-bold text-amber-400">連鎖路徑 B</span>
                            <p class="text-xs font-semibold text-slate-200">中國長鑫存儲等產能激增</p>
                        </div>
                        <i data-lucide="arrow-right" class="w-4 h-4 text-slate-500 group-hover:text-amber-400 transform group-hover:translate-x-1 transition-all"></i>
                    </button>

                    <button onclick="simulateChain(3)" id="chain-btn-3" class="chain-btn w-full text-left p-3.5 rounded-xl border border-slate-800 bg-slate-950 hover:border-rose-500/50 transition-all flex items-center justify-between group active:scale-98">
                        <div class="space-y-1">
                            <span class="text-xs font-bold text-rose-400">連鎖路徑 C</span>
                            <p class="text-xs font-semibold text-slate-200">AI 超級電腦功耗達 1.6MW</p>
                        </div>
                        <i data-lucide="arrow-right" class="w-4 h-4 text-slate-500 group-hover:text-rose-400 transform group-hover:translate-x-1 transition-all"></i>
                    </button>
                </div>

                <!-- Simulation Visual Board (Right) -->
                <div class="lg:col-span-8 bg-slate-950 border border-slate-800/80 p-6 rounded-2xl flex flex-col justify-between relative overflow-hidden">
                    <div class="absolute inset-0 bg-[radial-gradient(#1e293b_1px,transparent_1px)] [background-size:16px_16px] opacity-20"></div>

                    <div class="space-y-4 relative z-10">
                        <span class="text-xs font-bold text-slate-400 uppercase tracking-widest block">2. 骨牌連鎖傳導網絡</span>

                        <!-- Chain Nodes Graph -->
                        <div class="flex flex-col md:flex-row items-center justify-between gap-3 text-center py-2">
                            <div id="node-1" class="w-full md:w-1/4 p-3 rounded-xl border border-slate-800 bg-slate-900/50 text-xs font-bold text-slate-400 transition-all duration-300">
                                巨觀觸發事件
                            </div>
                            <div id="node-arrow-1" class="text-slate-700 font-black hidden md:block transition-colors">&rarr;</div>
                            <div id="node-2" class="w-full md:w-1/4 p-3 rounded-xl border border-slate-800 bg-slate-900/50 text-xs font-bold text-slate-400 transition-all duration-300">
                                中游材料與資金流
                            </div>
                            <div id="node-arrow-2" class="text-slate-700 font-black hidden md:block transition-colors">&rarr;</div>
                            <div id="node-3" class="w-full md:w-1/4 p-3 rounded-xl border border-slate-800 bg-slate-900/50 text-xs font-bold text-slate-400 transition-all duration-300">
                                台廠/供應鏈衝擊
                            </div>
                        </div>

                        <!-- Realtime Analysis Commentary Box -->
                        <div id="commentary-box" class="bg-slate-900/80 border border-slate-800 p-4 rounded-xl space-y-2 min-h-[110px] transition-all">
                            <div class="flex items-center gap-1.5 text-xs font-bold text-slate-400">
                                <i data-lucide="info" class="w-4 h-4"></i>
                                <span>沙盒 analysis 回饋</span>
                            </div>
                            <p class="text-xs text-slate-400 leading-relaxed">
                                尚未啟動模擬。請點擊左側任一連鎖路徑以載入情報專家交叉對比之連鎖骨牌效應路徑。
                            </p>
                        </div>
                    </div>
                </div>
            </div>
        </section>

        <!-- Comprehensive Reference Library (With Real-Time Filters) -->
        <section class="bg-slate-900 border border-slate-800/80 rounded-2xl p-6 space-y-6">
            <div class="flex flex-col lg:flex-row lg:items-center justify-between gap-4 border-b border-slate-800 pb-4">
                <div class="flex items-center gap-2">
                    <i data-lucide="book-open" class="text-indigo-400 w-5 h-5"></i>
                    <div>
                        <h3 class="font-bold text-slate-200">文獻檢索庫 (完整 30 篇情報來源列表)</h3>
                        <p class="text-xs text-slate-400 mt-0.5">提供 2026/05/18 - 05/22 所有來源參考文獻，支援實時模糊搜索與分類篩選</p>
                    </div>
                </div>

                <!-- Interactive Filters & Search -->
                <div class="flex flex-col sm:flex-row gap-3 w-full lg:w-auto">
                    <div class="relative flex-1 sm:w-72">
                        <i data-lucide="search" class="absolute left-3 top-2.5 w-4 h-4 text-slate-400"></i>
                        <input type="text" id="library-search" oninput="filterLibrary()" placeholder="搜尋文獻關鍵字、來源媒體或概念股..." class="w-full bg-slate-950 border border-slate-800 rounded-lg pl-9 pr-4 py-2 text-xs text-slate-100 placeholder-slate-500 focus:outline-none focus:border-indigo-500 transition-all">
                    </div>
                    <select id="library-filter" onchange="filterLibrary()" class="bg-slate-950 border border-slate-800 rounded-lg px-3 py-2 text-xs text-slate-300 focus:outline-none focus:border-indigo-500">
                        <option value="all">所有情報範疇</option>
                        <option value="semi">半導體與設備</option>
                        <option value="macro">宏觀經濟與匯率</option>
                        <option value="energy">石油化學與新能源</option>
                        <option value="fluorine">氟化工、液冷與特材</option>
                        <option value="satellite">太空與低軌衛星</option>
                    </select>
                </div>
            </div>

            <!-- Library Info Toast -->
            <div class="text-xs text-slate-400 bg-slate-950/60 p-3 rounded-xl border border-slate-800/60 flex items-center justify-between">
                <span>當前已載入 <strong id="matched-count" class="text-indigo-400">30</strong> 篇交叉核對文獻。點選右下角對應連結，可直接開啟各大新聞首頁獲取實時動態。</span>
            </div>

            <!-- Library Grid -->
            <div id="library-grid" class="grid grid-cols-1 md:grid-cols-2 lg:grid-cols-3 gap-4 max-h-[520px] overflow-y-auto pr-2">
                <!-- JS will inject library items dynamically -->
            </div>
        </section>

        <!-- New Section: Premium News Collection Database Link -->
        <section class="bg-gradient-to-r from-slate-900 via-indigo-950/30 to-slate-900 border border-indigo-900/40 p-6 rounded-2xl shadow-xl flex flex-col lg:flex-row items-center justify-between gap-6">
            <div class="flex items-start gap-4">
                <div class="bg-indigo-500/10 p-3 rounded-xl border border-indigo-500/20 text-indigo-400 shrink-0">
                    <i data-lucide="archive" class="w-6 h-6"></i>
                </div>
                <div class="space-y-1.5">
                    <h3 class="text-xs font-bold uppercase tracking-wider text-indigo-400">官方文獻存檔與知識庫門戶</h3>
                    <h4 class="text-base font-bold text-white">2026年5月第三週（05/18~05/22）產業情報與原始新聞完整對照資料庫</h4>
                    <p class="text-xs text-slate-400 leading-relaxed max-w-3xl">
                        本門戶收錄此期間所有追蹤之全球科技政策、半導體先進製程、總經利差防線、特化與無氟液冷散熱技術之原始新聞內容。如果您需要深入查閱這段時間完整的新聞文獻資料，我們已為您將所有詳盡數據與文獻段落備份至雲端。歡迎點選右側連結進入專家級合規檢索系統。
                    </p>
                </div>
            </div>
            <a href="https://docs.google.com/document/d/1X1HW7CP4knPO0_xjVvLmpLrmOsLOvzMOeSnbhFVlzn8/edit?usp=sharing" target="_blank" rel="noopener noreferrer" class="flex items-center gap-2 bg-indigo-600 hover:bg-indigo-500 text-white font-bold px-5 py-3 rounded-xl text-xs transition-all shadow-lg shadow-indigo-600/20 shrink-0 group active:scale-95">
                <span>開啟原始新聞資料庫</span>
                <i data-lucide="external-link" class="w-4 h-4 group-hover:translate-x-0.5 group-hover:-translate-y-0.5 transition-transform"></i>
            </a>
        </section>
    </main>

    <!-- Footer -->
    <footer class="border-t border-slate-800 bg-slate-950 py-6 text-center text-xs text-slate-500 space-y-1">
        <p>© 2026 全球重點新聞與產業趨勢智慧決策系統 Pro</p>
        <p class="text-[10px] text-slate-600">專為決策高層設計 · 交叉對比沙盒 · 數據最後更新日期：2026/05/22</p>
    </footer>

    <!-- Custom Toast / Alarm Alert Notification Box -->
    <div id="toast-box" class="fixed bottom-6 right-6 z-50 bg-indigo-900 border border-indigo-500 text-white px-5 py-4 rounded-xl shadow-2xl shadow-indigo-950/80 max-w-sm flex items-start gap-3 hidden transition-all duration-300">
        <div class="p-1.5 bg-indigo-800 rounded-lg text-indigo-300">
            <i data-lucide="bell" class="w-5 h-5 animate-bounce"></i>
        </div>
        <div>
            <h5 class="text-xs font-bold" id="toast-title">智慧通報系統</h5>
            <p class="text-[11px] text-indigo-200 mt-1 leading-relaxed" id="toast-message">情報模型已與最新數據庫建立安全握手通訊。</p>
        </div>
    </div>

    <!-- Export Modal -->
    <div id="export-modal" class="fixed inset-0 bg-black/70 backdrop-blur-sm z-50 flex items-center justify-center p-4 hidden">
        <div class="bg-slate-900 border border-slate-800 rounded-2xl max-w-md w-full p-6 space-y-4 shadow-2xl relative">
            <button onclick="closeExportModal()" class="absolute right-4 top-4 text-slate-400 hover:text-white">
                <i data-lucide="x" class="w-5 h-5"></i>
            </button>
            <div class="flex items-center gap-2 border-b border-slate-800 pb-3">
                <i data-lucide="file-output" class="text-indigo-400 w-5 h-5"></i>
                <h4 class="font-bold text-slate-200">匯出專家級決策情報包</h4>
            </div>
            <p class="text-xs text-slate-300 leading-relaxed">
                系統將自動統整當週「2nm/CoWoS 技術地圖」、「去 PFAS 特材替代商機」、「信實工業 vs 寧德時代技術紅線」以及「SpaceX 1.75兆美元估值帶動的台廠地面站效益」。
            </p>
            <div class="grid grid-cols-2 gap-3 pt-2">
                <button onclick="simulateReportDownload('Briefing_Executive_Report_2026W21.pdf')" class="flex flex-col items-center justify-center p-4 bg-slate-950 border border-slate-800 rounded-xl hover:border-indigo-500/40 transition-all group">
                    <i data-lucide="file-text" class="w-8 h-8 text-indigo-400 group-hover:scale-110 transition-transform"></i>
                    <span class="text-xs font-bold text-slate-200 mt-2">PDF 決策簡報</span>
                    <span class="text-[9px] text-slate-500 mt-0.5">適合用於董事會</span>
                </button>
                <button onclick="simulateReportDownload('Full_Library_Database_2026W21.xlsx')" class="flex flex-col items-center justify-center p-4 bg-slate-950 border border-slate-800 rounded-xl hover:border-indigo-500/40 transition-all group">
                    <i data-lucide="database" class="w-8 h-8 text-emerald-400 group-hover:scale-110 transition-transform"></i>
                    <span class="text-xs font-bold text-slate-200 mt-2">EXCEL 資料庫</span>
                    <span class="text-[9px] text-slate-500 mt-0.5">包含 30 篇完整文獻</span>
                </button>
            </div>
            <div id="modal-download-progress" class="hidden space-y-1.5 pt-2">
                <div class="flex items-center justify-between text-[11px] text-indigo-400">
                    <span id="download-lbl">正在彙整分析數據...</span>
                    <span id="download-pct">0%</span>
                </div>
                <div class="w-full bg-slate-950 h-1.5 rounded-full overflow-hidden">
                    <div id="download-progress-bar" class="bg-indigo-600 h-full w-0 transition-all"></div>
                </div>
            </div>
        </div>
    </div>

    <!-- Script Block -->
    <script>
        // Real-world database containing all items and summaries from the uploaded text
        const completeLibrary = [
            {
                id: 1,
                title: "石化類股逆勢走強是短期現象嗎？盤中資金輪動與族群防禦性解析",
                source: "Readmo.ai - 投資網誌",
                url: "https://readmo.ai/",
                category: "energy",
                excerpt: "大盤與櫃買同步失守均線之際，台塑化、中石化、新海逆勢飆高。這並非趨勢反轉，而是資金往低基期、低估值與具備中東局勢油價支撐的防禦性板塊移防。",
                concepts: "景氣循環、避風港、台塑化、中石化",
                date: "2026-05-20",
                badge: "防禦性配置"
            },
            {
                id: 2,
                title: "艾司摩爾執行長：AI需求暴增全球晶片供應恐長期吃緊",
                source: "鉅亨網",
                url: "https://news.cnyes.com/",
                category: "semi",
                excerpt: "ASML執行長福克指出，AI、衛星網路與機器人需求快速爆發，全球晶片市場至2030年可達1.5兆美元.High NA EUV 已接近量產，英特爾為首批客戶.警告進一步對中銷售管制恐逼中方加速自主化。",
                concepts: "ASML、EUV、High NA、產能瓶頸、出口管制",
                date: "2026-05-19",
                badge: "關鍵設備"
            },
            {
                id: 3,
                title: "黃仁勳訪中還是賣不掉輝達晶片？唐湘龍曝中國早有備案",
                source: "Yahoo新聞",
                url: "https://tw.news.yahoo.com/",
                category: "semi",
                excerpt: "陳鳳馨指出，中國正加速蝕刻機、薄膜沈積、清洗、離子注入等國產替代自給，且川普證實習近平表示中國「不想買、想要自己造」，美對中晶片管制反壓縮美股科技估值。",
                concepts: "輝達、川習會、國產替代、華為、半導體去美化",
                date: "2026-05-19",
                badge: "去美化風暴"
            },
            {
                id: 4,
                title: "團結香港基金建議加速氫能產業發展",
                source: "Now 新聞",
                url: "https://news.now.com/",
                category: "energy",
                excerpt: "發表報告建議香港在貨櫃碼頭等重型車輛密集的偏遠地區，以氫能取代高碳排柴油發電機，並在「十五五」規劃中加速港口加氫站基礎建設。",
                concepts: "碳中和、加氫站、重型交通、沼氣製氫",
                date: "2026-05-19",
                badge: "綠能政策"
            },
            {
                id: 5,
                title: "艾司摩爾與塔塔電子擬建印度首座12吋晶圓廠",
                source: "台灣大紀元",
                url: "https://www.epochtimes.com/",
                category: "semi",
                excerpt: "ASML與印度塔塔電子簽署合作備忘錄（MOU），支援印度打造首座12吋先進成熟晶圓廠，加速南亞半導體自主化與供應鏈多元化。",
                concepts: "ASML、塔塔集團、印度製造、成熟製程",
                date: "2026-05-18",
                badge: "供應鏈分散"
            },
            {
                id: 6,
                title: "從8 吋測試晶圓去化，看俄國成熟製程產現況",
                source: "TechNews 科技新報",
                url: "https://technews.tw/",
                category: "semi",
                excerpt: "俄羅斯正透過進口台灣「測試晶圓」（Test Wafer）等非管制物資，維持其國內8吋與12吋成熟製程晶圓廠的生產運作，突顯管制漏洞。",
                concepts: "地緣政治、成熟製程、測試晶圓、出口管制",
                date: "2026-05-18",
                badge: "地緣博弈"
            },
            {
                id: 7,
                title: "傳產業連二月正成長：受惠 AI 電子化學品急單與中東局勢",
                source: "經濟日報",
                url: "https://money.udn.com/",
                category: "macro",
                excerpt: "4月基本金屬及機械接單回暖，年增4.5%及23.4%。半導體擴廠拉升化學品與自動化設備訂單，中東戰爭則帶動鋼、銅價格上行，但鋼市需求依然保守。",
                concepts: "銅箔、銅基板、電子特化、基本金屬、機械",
                date: "2026-05-20",
                badge: "傳產回暖"
            },
            {
                id: 8,
                title: "經部520繳成績單：AI浪潮助推台股上4萬點五大信賴產業產值飆破10兆元",
                source: "鉅亨網",
                url: "https://news.cnyes.com/",
                category: "macro",
                excerpt: "行政院預計今年經濟成長率可達7.71%，經濟部長龔明鑫強調AI浪潮將助推台股高階產能，五大信賴產業產值突破10兆元大關，充當百業堅實後盾。",
                concepts: "五大信賴產業、龔明鑫、GDP、經濟成果",
                date: "2026-05-20",
                badge: "政策政績"
            },
            {
                id: 9,
                title: "PFAS 與含氟材料的戰略轉向：電子與化學產業邁向永續之路",
                source: "IEK產業情報網",
                url: "https://ieknet.iek.org.tw/",
                category: "fluorine",
                excerpt: "歐盟REACH對PFAS（全氟多氟烷基）環境毒性限制升級。半導體蝕刻及資料中心高規散熱液正加速尋求矽系材料與無氟冷卻液等替代技術，引發特材轉骨革命。",
                concepts: "REACH、PFAS、無氟、特化革命、生質高分子",
                date: "2026-05-19",
                badge: "關鍵特材"
            },
            {
                id: 10,
                title: "陸氫能產業深度洗牌年底四成公司恐消失",
                source: "經濟日報",
                url: "https://money.udn.com/",
                category: "energy",
                excerpt: "中國氫能爆發價格戰與出清，上海氫通能源齊志剛預警：年底40%氫能公司將消失，2029年僅剩10%。綠氫成本仍遠高於傳統煤製氫，且供需區域錯配問題。",
                concepts: "氫能洗牌、綠氫、價格戰、政策補貼",
                date: "2026-05-20",
                badge: "產能清洗"
            },
            {
                id: 11,
                title: "看好中國開放美AI晶片進口黃仁勳：台灣仍居半導體關鍵地位",
                source: "Yahoo新聞",
                url: "https://tw.news.yahoo.com/",
                category: "semi",
                excerpt: "黃仁勳隨同美國總統川普出席美中峰會後表示，雖然此次「川習會」並未就美國對中晶片出口限制取得具體突破，但他對未來發展仍持樂觀看法。他預測市場終將逐步開放。",
                concepts: "輝達、川普、美中峰會、台積電",
                date: "2026-05-19",
                badge: "巨頭喊話"
            },
            {
                id: 12,
                title: "產業政策：Intel與Samsung分食訂單對台積電地位的衝擊與實質影響",
                source: "科技產業資訊室",
                url: "https://iknow.stpi.narl.org.tw/",
                category: "semi",
                excerpt: "台積電高階先進封裝產能供不應求，促使 SK 海力士與 Apple 將部分封裝/低階代工轉移至 Intel EMIB。但這反倒幫助台積電策略性減壓，優化利潤更高的2nm/A16產能。",
                concepts: "先進封裝、EMIB、產能外溢、台積電、策略性減壓",
                date: "2026-05-18",
                badge: "產能分流"
            },
            {
                id: 13,
                title: "美債殖利率飆高衝擊科技股，美光與 SanDisk 反彈",
                source: "財經快訊",
                url: "https://finance.yahoo.com/",
                category: "macro",
                excerpt: "高天期美債殖利率逼近多年高點，壓抑那斯達克科技股高估值，但美光、SanDisk 因 HBM 及企業 SSD 價格強漲預期，股價逆勢反彈2.5~3.7%。",
                concepts: "美債利率、美光、漲價預期、高估值壓縮",
                date: "2026-05-19",
                badge: "估值分化"
            },
            {
                id: 14,
                title: "三星大罷工危機：急轉彎勞資達成暫時協議、全面罷工喊卡",
                source: "經濟日報",
                url: "https://money.udn.com/",
                category: "semi",
                excerpt: "原定21日爆發的萬人總罷工，在南韓僱傭勞動部長金榮訓緊急主持談判6小時後，於20日深夜轉彎。勞資雙方就 DS 獲利分配比率達成暫時協議，交由工會5/22-5/27投票表決。",
                concepts: "三星電子、大罷工、金榮訓、分紅協議、產量控制",
                date: "2026-05-20",
                badge: "危機暫解"
            },
            {
                id: 15,
                title: "AI 記憶體戰火升溫：三星、SK 海力士研發支出最高暴增 68％",
                source: "科技快訊",
                url: "https://technews.tw/",
                category: "semi",
                excerpt: "第一季 SK 海力士研發費用年增高達 68.3%，人事與材料大增。三星研發突破 11 兆韓元，加速第六代 1c DRAM 量產與 HBM4 底部 4nm 製程控制 Die 開發。",
                concepts: "R&D支出、HBM4、Base Die、SK海力士、三星",
                date: "2026-05-15",
                badge: "研發巨資"
            },
            {
                id: 16,
                title: "半導體新戰局！台積十年AI藍圖6大重點",
                source: "台積電2026技術論壇",
                url: "https://www.tsmc.com/",
                category: "semi",
                excerpt: "揭露先進製程 2 奈米良率進程優於 3 奈米。CoWoS 良率已破 98%，2028-2029年將分別推進至支援整合 20 及 24 顆 HBM，並主推結合 COUPE 矽光子全光傳輸架構。",
                concepts: "COUPE、矽光子、CoWoS、SoW、SoIC、2nm良率",
                date: "2026-05-18",
                badge: "技術論壇"
            },
            {
                id: 17,
                title: "三星工會與資方拉扯，合約價飆高引市場搶卡 2027 供貨",
                source: "南韓產經",
                url: "https://www.yna.co.kr/",
                category: "semi",
                excerpt: "三大原廠 2026 年產能已全數售罄，供應鏈正加速卡位 2027 年供貨。罷工陰影導致模組合約價單季暴漲 4 成，現貨市場提前爆發搶貨潮。",
                concepts: "DRAM、合約價、現貨溢價、搶產能",
                date: "2026-05-21",
                badge: "產能緊俏"
            },
            {
                id: 18,
                title: "中國太陽能產業發展放緩 協鑫科技切入 LFP 與矽碳負極轉型電池材料平台",
                source: "彭步社 / 綠能報導",
                url: "https://www.bloomberg.com/",
                category: "energy",
                excerpt: "太陽能極度過剩，巨頭協鑫連續兩年虧損，2025淨虧28.7億人民幣。協鑫利用甲矽烷資源優勢，於樂山建年產 20 萬噸 LFP 電池平台，轉型分散風險。",
                concepts: "協鑫科技、LFP、矽碳負極、太陽能過剩、淨虧損",
                date: "2026-05-20",
                badge: "特材轉型"
            },
            {
                id: 19,
                title: "央行強勢調節 新台幣守31.6元",
                source: "工商時報",
                url: "https://www.chinatimes.com/",
                category: "macro",
                excerpt: "中美利差懸殊與外資大幅匯出使新台幣探底。央行盤中一路強勢阻貶、由放任轉為精細調節，尾盤終場小升收於 31.643 元，維持匯價穩定。",
                concepts: "新台幣、阻貶、拋匯、利差倒掛",
                date: "2026-05-20",
                badge: "匯率調節"
            },
            {
                id: 20,
                title: "台GDP上看9.5％ 渣打示警K型經濟成長分化",
                source: "中時電子報",
                url: "https://www.chinatimes.com/",
                category: "macro",
                excerpt: "外資渣打大膽預估台灣 GDP 達 9.5%，領先官方。但提醒，佔台灣高達 90% 就業的非科技傳統產業仍深陷外需寒冬與電價、能源通膨的夾殺。",
                concepts: "K型經濟、胡東安、通膨預期、實質薪資倒退",
                date: "2026-05-20",
                badge: "分化警訊"
            },
            {
                id: 21,
                title: "520執政兩周年》賴總統 力推 4 願景與中小微千億多元振興",
                source: "工商時報",
                url: "https://www.chinatimes.com/",
                category: "macro",
                excerpt: "賴清德公佈四大願景。包含守護台海現狀防線、投入千億振興中小微企業數位與淨零轉型，並推動 0-18 歲每月 5,000 元成長津貼搶救少子化。",
                concepts: "中小微企業、0-18歲津貼、少子化戰略、對美軍購",
                date: "2026-05-20",
                badge: "執政願景"
            },
            {
                id: 22,
                title: "連15紅！外銷訂單寫最強4月 衝上874億美元",
                source: "聯合新聞網",
                url: "https://udn.com/",
                category: "macro",
                excerpt: "4月外銷接單衝上史上次高，年增高達 48.1%。電子資通信類因 AI 出口暴增九成；值得注意是傳產如機械成長 23% 最亮眼。",
                concepts: "外銷接單、資通信、機械、正成長",
                date: "2026-05-20",
                badge: "外銷數據"
            },
            {
                id: 23,
                title: "其曜發表2P DLC雙相直接液冷整櫃解決方案",
                source: "工商時報",
                url: "https://www.chinatimes.com/",
                category: "fluorine",
                excerpt: "應對 AI 單機櫃功耗激增至 1.6MW 與歐盟 PFAS 禁令，其曜推出雙相直接液冷 DLC 整櫃散熱，解決高壓直流系統散熱難題。",
                concepts: "其曜、DLC、散熱、去PFAS、高壓直流",
                date: "2026-05-20",
                badge: "液冷革命"
            },
            {
                id: 24,
                title: "記憶體股爆量殺盤！AI 需求見頂疑慮與 2027 供給恐慌",
                source: "鉅亨網",
                url: "https://news.cnyes.com/",
                category: "semi",
                excerpt: "長鑫存儲擴充 DDR5 產量、希捷 Mosley 拒蓋新廠暗示 AI 庫存修正，以及 Cerebras IPO 提出「晶圓級處理器無須使用 HBM」，多項利空引發記憶體板塊暴跌踩踏。",
                concepts: "南亞科跌停、群聯、Cerebras、HBM需求、長鑫存儲",
                date: "2026-05-19",
                badge: "板塊重挫"
            },
            {
                id: 25,
                title: "輝達財報本周登場 市場聚焦 AI 需求、毛利率與中國市場變數",
                source: "外商投顧",
                url: "https://finance.yahoo.com/",
                category: "semi",
                excerpt: "美銀維持買進評等，預期單季營收超出市場 20~40 億美元。五大看點：Rubin 架構 2026 釋放時程、75% 毛利率保衛線、ASIC 威脅及中國 H200 准入政策。",
                concepts: "輝達財報、Rubin架構、毛利率、美銀評等",
                date: "2026-05-20",
                badge: "焦點財報"
            },
            {
                id: 26,
                title: "台股重挫、失守月線，低軌衛星族群與太空供應鏈逆勢飆漲",
                source: "工商時報",
                url: "https://www.chinatimes.com/",
                category: "satellite",
                excerpt: "台股跌破月線。但馬斯克 SpaceX 籌備 IPO 估值 1.75 兆美元催化，敬鵬、事欣科強拉兩根漲停。遠傳與亞馬遜 Amazon Leo 合作簽經銷，低軌鏈大火。",
                concepts: "SpaceX IPO、事欣科、敬鵬、遠傳、地面站",
                date: "2026-05-19",
                badge: "資金移防"
            },
            {
                id: 27,
                title: "安謀（Arm）遭美國 FTC 反壟斷調查 跨足自研 AI 晶片引爆客戶疑慮",
                source: "TechNews 科技新報",
                url: "https://technews.tw/",
                category: "semi",
                excerpt: "Arm 推出自研資料中心 AGI CPU 轉變為競爭者，被高通告發。FTC、南韓與歐盟啟動反壟斷調查，質疑授權不公、又當裁判又當選手。",
                concepts: "Arm、FTC、反壟斷、高通訴訟、自研CPU",
                date: "2026-05-19",
                badge: "反壟斷"
            },
            {
                id: 28,
                title: "三星電子 HBM 良率大突破 HBM3E 核心 DRAM 良率衝上 92％",
                source: "南韓產經新聞",
                url: "https://www.yna.co.kr/",
                category: "semi",
                excerpt: "三星派駐 500 人攻關團隊，在短時間將 1b DRAM 的冷態良率推上 92.0% 進入成熟期。用於 HBM4 的 1c DRAM 製程良率亦打破 75.0% 門檻。",
                concepts: "HBM3E、1b DRAM良率、1c DRAM、成熟期、生產穩定度",
                date: "2026-05-20",
                badge: "良率突破"
            },
            {
                id: 29,
                title: "中國收緊鋰電池技術輸出紅線 信實工業改向寧德時代直接採購",
                source: "經濟日報",
                url: "https://money.udn.com/",
                category: "energy",
                excerpt: "印度信實工業因中國對電芯技術封鎖限制，宣告與海辰儲能及寧德技術移轉協議破裂，被迫轉為向寧德時代直接購買儲能成品系統，印度電芯自製夢碎。",
                concepts: "寧德時代、信實工業、海辰儲能、儲能系統、技術封鎖",
                date: "2026-05-20",
                badge: "技術圍堵"
            },
            {
                id: 30,
                title: "IEA 預估電動車全球市占衝 30% 電池價格下降提振買氣",
                source: "IEA報告",
                url: "https://www.iea.org/",
                category: "energy",
                excerpt: "國際能源署（IEA）指出中東危機使化石燃料昂貴，反倒促使歐、亞、拉美加快補貼電氣化。預期今年電動車銷量達 2,300 萬輛，佔新車 30%。",
                concepts: "IEA、油價飆漲、電動車、補貼延長",
                date: "2026-05-20",
                badge: "電氣化"
            }
        ];

        // Global Page State
        let currentTab = 'semi';

        // Initialize App
        window.onload = function() {
            lucide.createIcons();
            renderLibrary(completeLibrary);
            simulateChain(1); // Default Chain Reaction
        };

        // DOM dynamic rendering for reference library
        function renderLibrary(items) {
            const grid = document.getElementById('library-grid');
            grid.innerHTML = '';

            document.getElementById('matched-count').innerText = items.length;

            if (items.length === 0) {
                grid.innerHTML = `
                    <div class="col-span-full py-12 text-center text-slate-500 text-xs">
                        找不到符合過濾條件的情報文獻。請嘗試其他搜尋關鍵字或分類。
                    </div>
                `;
                return;
            }

            items.forEach(item => {
                let badgeColor = '';
                switch (item.category) {
                    case 'semi':
                        badgeColor = 'bg-indigo-500/10 text-indigo-300 border-indigo-500/20';
                        break;
                    case 'macro':
                        badgeColor = 'bg-emerald-500/10 text-emerald-300 border-emerald-500/20';
                        break;
                    case 'energy':
                        badgeColor = 'bg-amber-500/10 text-amber-300 border-amber-500/20';
                        break;
                    case 'fluorine':
                        badgeColor = 'bg-rose-500/10 text-rose-300 border-rose-500/20';
                        break;
                    case 'satellite':
                        badgeColor = 'bg-sky-500/10 text-sky-300 border-sky-500/20';
                        break;
                    default:
                        badgeColor = 'bg-slate-500/10 text-slate-300 border-slate-500/20';
                }

                const cardHtml = `
                    <div class="bg-slate-950/80 border border-slate-850 p-4 rounded-xl flex flex-col justify-between hover:border-slate-700 transition-all group glow-border">
                        <div class="space-y-2">
                            <div class="flex items-center justify-between">
                                <span class="text-[9px] px-2 py-0.5 rounded font-bold border ${badgeColor}">
                                    ${item.category === 'semi' ? '半導體設備' : item.category === 'macro' ? '總經與政策' : item.category === 'energy' ? '綠能與石化' : item.category === 'fluorine' ? '去氟特材液冷' : '低軌衛星航太'}
                                </span>
                                <span class="text-[9px] font-black text-slate-500 tracking-wider">${item.badge}</span>
                            </div>
                            <h4 class="text-xs md:text-sm font-bold text-slate-100 group-hover:text-indigo-400 transition-colors line-clamp-2">
                                ${item.title}
                            </h4>
                            <p class="text-[11px] text-slate-400 leading-relaxed line-clamp-3">
                                ${item.excerpt}
                            </p>
                        </div>
                        <div class="pt-3 mt-3 border-t border-slate-800/60 flex items-center justify-between">
                            <div class="space-y-0.5">
                                <span class="text-[10px] text-slate-500 block">${item.source}</span>
                                <span class="text-[9px] text-slate-600 block">${item.date}</span>
                            </div>
                            <a href="${item.url}" target="_blank" rel="noopener noreferrer" class="flex items-center gap-1 text-[10px] text-indigo-400 hover:text-indigo-300 font-bold transition-all shrink-0">
                                連結原文 <i data-lucide="external-link" class="w-3 h-3"></i>
                            </a>
                        </div>
                    </div>
                `;
                grid.insertAdjacentHTML('beforeend', cardHtml);
            });
            lucide.createIcons();
        }

        // Library filter logic
        function filterLibrary() {
            const query = document.getElementById('library-search').value.toLowerCase();
            const category = document.getElementById('library-filter').value;

            const filtered = completeLibrary.filter(item => {
                const matchText = item.title.toLowerCase().includes(query) ||
                                  item.excerpt.toLowerCase().includes(query) ||
                                  item.concepts.toLowerCase().includes(query) ||
                                  item.source.toLowerCase().includes(query);
                const matchCat = category === 'all' || item.category === category;
                return matchText && matchCat;
            });

            renderLibrary(filtered);
        }

        // Tab Swapping
        function switchTab(tabId) {
            document.querySelectorAll('.tab-content').forEach(el => el.classList.add('hidden'));
            document.querySelectorAll('.tab-btn').forEach(btn => {
                btn.classList.remove('bg-indigo-600', 'text-white', 'shadow');
                btn.classList.add('text-slate-400', 'hover:text-white');
            });

            document.getElementById(`content-${tabId}`).classList.remove('hidden');
            const activeBtn = document.getElementById(`tab-${tabId}`);
            activeBtn.classList.remove('text-slate-400', 'hover:text-white');
            activeBtn.classList.add('bg-indigo-600', 'text-white', 'shadow');
            currentTab = tabId;
        }

        // Sandbox Chain Reaction Simulator
        function simulateChain(chainId) {
            // Reset active button states
            document.querySelectorAll('.chain-btn').forEach(btn => {
                btn.classList.remove('border-indigo-500', 'border-amber-500', 'border-rose-500', 'bg-indigo-950/30', 'bg-amber-950/30', 'bg-rose-950/30');
            });

            const node1 = document.getElementById('node-1');
            const node2 = document.getElementById('node-2');
            const node3 = document.getElementById('node-3');
            const arrow1 = document.getElementById('node-arrow-1');
            const arrow2 = document.getElementById('node-arrow-2');
            const commBox = document.getElementById('commentary-box');

            // Reset node active colors
            node1.className = "w-full md:w-1/4 p-3 rounded-xl border border-slate-800 bg-slate-900/50 text-xs font-bold text-slate-400 transition-all duration-300";
            node2.className = "w-full md:w-1/4 p-3 rounded-xl border border-slate-800 bg-slate-900/50 text-xs font-bold text-slate-400 transition-all duration-300";
            node3.className = "w-full md:w-1/4 p-3 rounded-xl border border-slate-800 bg-slate-900/50 text-xs font-bold text-slate-400 transition-all duration-300";
            arrow1.className = "text-slate-700 font-black hidden md:block transition-colors";
            arrow2.className = "text-slate-700 font-black hidden md:block transition-colors";

            if (chainId === 1) {
                document.getElementById('chain-btn-1').classList.add('border-indigo-500', 'bg-indigo-950/30');

                node1.innerText = "美債高利率倒掛 293點";
                node1.className = "w-full md:w-1/4 p-3 rounded-xl border border-indigo-500/80 bg-indigo-950/40 text-xs font-bold text-indigo-300 transition-all duration-300";

                node2.innerText = "外資匯出 / 亞幣阻貶";
                node2.className = "w-full md:w-1/4 p-3 rounded-xl border border-indigo-500/60 bg-indigo-950/20 text-xs font-bold text-indigo-300 transition-all duration-300";

                node3.innerText = "新台幣硬守 31.6 防線";
                node3.className = "w-full md:w-1/4 p-3 rounded-xl border border-indigo-500/40 bg-indigo-950/10 text-xs font-bold text-indigo-300 transition-all duration-300";

                arrow1.className = "text-indigo-500 font-black hidden md:block transition-colors";
                arrow2.className = "text-indigo-500 font-black hidden md:block transition-colors";

                commBox.innerHTML = `
                    <div class="flex items-center gap-1.5 text-xs font-bold text-indigo-400">
                        <i data-lucide="zap" class="w-4 h-4"></i>
                        <span>專家評估：高利差套利外流</span>
                    </div>
                    <p class="text-xs text-slate-300 leading-relaxed">
                        美債高利率使套利誘因極大，外資連續12個月減持陸債，並從台北匯市流出。台灣央行一改放任態度，強勢進場精細調節，硬守31.643元，主要是防止因急速貶值引發「輸入型能源通膨」，加劇台灣內部 K型經濟民生產業之痛苦指數。
                    </p>
                `;
            } else if (chainId === 2) {
                document.getElementById('chain-btn-2').classList.add('border-amber-500', 'bg-amber-950/30');

                node1.innerText = "長鑫存儲月產破30萬片";
                node1.className = "w-full md:w-1/4 p-3 rounded-xl border border-amber-500/80 bg-amber-950/40 text-xs font-bold text-amber-300 transition-all duration-300";

                node2.innerText = "2027 DRAM 過剩疑慮";
                node2.className = "w-full md:w-1/4 p-3 rounded-xl border border-amber-500/60 bg-amber-950/20 text-xs font-bold text-amber-300 transition-all duration-300";

                node3.innerText = "台股記憶體類股踩踏跌停";
                node3.className = "w-full md:w-1/4 p-3 rounded-xl border border-amber-500/40 bg-amber-950/10 text-xs font-bold text-amber-300 transition-all duration-300";

                arrow1.className = "text-amber-500 font-black hidden md:block transition-colors";
                arrow2.className = "text-amber-500 font-black hidden md:block transition-colors";

                commBox.innerHTML = `
                    <div class="flex items-center gap-1.5 text-xs font-bold text-amber-400">
                        <i data-lucide="zap" class="w-4 h-4"></i>
                        <span>專家評估：DRAM週期反轉恐慌</span>
                    </div>
                    <p class="text-xs text-slate-300 leading-relaxed">
                        中國長鑫存儲 DDR5 規格升至 8000MT/s、產量急劇釋放。加上 Cerebras 晶圓級運算架構威脅，使 HBM 的壟斷護城河出現疑慮。投資人對「AI 記憶體需求觸頂」神經緊繃，引爆南亞科、華邦電與群聯的恐慌性踩踏殺盤。
                    </p>
                `;
            } else if (chainId === 3) {
                document.getElementById('chain-btn-3').classList.add('border-rose-500', 'bg-rose-950/30');

                node1.innerText = "單機櫃功耗直奔 1.6MW";
                node1.className = "w-full md:w-1/4 p-3 rounded-xl border border-rose-500/80 bg-rose-950/40 text-xs font-bold text-rose-300 transition-all duration-300";

                node2.innerText = "歐盟 PFAS 特化禁令 REACH";
                node2.className = "w-full md:w-1/4 p-3 rounded-xl border border-rose-500/60 bg-rose-950/20 text-xs font-bold text-rose-300 transition-all duration-300";

                node3.innerText = "雙相直接液冷 DLC 技術落地";
                node3.className = "w-full md:w-1/4 p-3 rounded-xl border border-rose-500/40 bg-rose-950/10 text-xs font-bold text-rose-300 transition-all duration-300";

                arrow1.className = "text-rose-500 font-black hidden md:block transition-colors";
                arrow2.className = "text-rose-500 font-black hidden md:block transition-colors";

                commBox.innerHTML = `
                    <div class="flex items-center gap-1.5 text-xs font-bold text-rose-400">
                        <i data-lucide="zap" class="w-4 h-4"></i>
                        <span>專家評估：散熱極限與特化去氟</span>
                    </div>
                    <p class="text-xs text-slate-300 leading-relaxed">
                        功耗暴增 200 倍逼退傳統高速銅線，全面推動光電整合（COUPE/CPO）。而歐盟 PFAS 強制退場令，使得傳統含氟冷卻液瀕臨禁制。這將極大地推升不含 PFAS 的無氟雙相直接液冷（DLC）特化化學品之戰略主權與利潤空間。
                    </p>
                `;
            }
            lucide.createIcons();
        }

        // Toast trigger helper
        function showToast(title, message) {
            const box = document.getElementById('toast-box');
            document.getElementById('toast-title').innerText = title;
            document.getElementById('toast-message').innerText = message;

            box.classList.remove('hidden');
            setTimeout(() => {
                box.classList.add('hidden');
            }, 4500);
        }

        // Open/Close Modal
        function openExportModal() {
            document.getElementById('export-modal').classList.remove('hidden');
        }

        // Close Modal
        function closeExportModal() {
            document.getElementById('export-modal').classList.add('hidden');
            document.getElementById('modal-download-progress').classList.add('hidden');
            document.getElementById('download-progress-bar').style.width = '0%';
            document.getElementById('download-pct').innerText = '0%';
        }

        // Simulate Download Progress with high reliability
        function simulateReportDownload(filename) {
            const progress = document.getElementById('modal-download-progress');
            const bar = document.getElementById('download-progress-bar');
            const lbl = document.getElementById('download-lbl');
            const pct = document.getElementById('download-pct');

            progress.classList.remove('hidden');
            bar.style.width = '0%';

            let percentage = 0;
            const timer = setInterval(() => {
                percentage += 10;
                bar.style.width = `${percentage}%`;
                pct.innerText = `${percentage}%`;

                if (percentage === 30) {
                    lbl.innerText = "正在交叉比對 30 篇全球趨勢文獻...";
                } else if (percentage === 60) {
                    lbl.innerText = "正在彙整台積電2nm及無氟冷卻液架構...";
                } else if (percentage === 90) {
                    lbl.innerText = "寫入情報專家 W21 董事會安全密鑰...";
                } else if (percentage === 100) {
                    clearInterval(timer);
                    lbl.innerText = `下載成功：${filename}`;
                    setTimeout(() => {
                        closeExportModal();
                        showToast("匯出成功", `${filename} 已儲存至您本地下載路徑。`);
                    }, 1200);
                }
            }, 250);
        }
    </script>
</body>
</html>
# Out:
#   File "/tmp/ipykernel_3609/2018011072.py", line 20
#     width: 6px;
#            ^
# SyntaxError: invalid decimal literal
